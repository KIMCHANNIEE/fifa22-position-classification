# %% [markdown]
# # 1-4. Supervised Learning
# 이번 실습에서는 머신러닝의 대표적인 방법인 지도 학습을 알아보도록 하겠습니다.<br>
# <br>
# 지도 학습(Supervised Learning)은 비지도 학습과 다르게 **정답 레이블(Label)**이 있습니다.<br>
# 주어진 데이터를 기반으로 정답 레이블을 잘 맞히도록 가중치를 학습하는 과정을 **지도 학습**이라고 할 수 있습니다.<br>
# 지도 학습은 또 크게 2가지 문제로 나뉩니다. 바로 **분류(Classification)**와 **회귀(Regression)**입니다.<br>
# 분류는 범주형 데이터를 예측하는 것, 회귀는 연속형 데이터를 예측하는 것으로 생각하면 쉽습니다.<br>
# 오늘 진행할 과제는 **축구 선수들의 능력치로 포지션을 예측**하는 분류 문제입니다.<br>
# <br>
# **학습 목표**
# 1. 학습 데이터 전처리
# 2. Scikit-Learn 라이브러리 활용법
# 3. 파이프라인 생성 후 학습
# 4. 모델 평가(Metric)
# 5. 하이퍼 파라미터 튜닝

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 기본적으로 필요한 시각화 라이브러리를 불러오기
from matplotlib import font_manager, rc, rcParams
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 시각화 설정

# Seaborn에서 기본 스타일을 지정할 수 있습니다.
sns.set_style('whitegrid')

# %% [markdown]
# ## 데이터 전처리

# %%
# Pandas 및 정규표현식 불러오기
import pandas as pd
import re

# %%
import os

path = '/content/drive/MyDrive/FIFA22_official_data.csv'
df = pd.read_csv(path , encoding = 'utf-8'); df
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16705  240558    18 L. Clayton   17
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
# 16709  178453    07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# 16705  https://cdn.sofifa.com/players/240/558/18_60.png     England
# 16706  https://cdn.sofifa.com/players/262/846/22_60.png     Romania
# 16707  https://cdn.sofifa.com/players/241/317/21_60.png    China PR
# 16708  https://cdn.sofifa.com/players/259/646/22_60.png       India
# 16709  https://cdn.sofifa.com/players/178/453/07_60.png       Italy
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/pt.png       88         89
# 1          https://cdn.sofifa.com/flags/de.png       87         88
# 2          https://cdn.sofifa.com/flags/uy.png       88         88
# 3          https://cdn.sofifa.com/flags/be.png       91         91
# 4          https://cdn.sofifa.com/flags/ar.png       84         84
# ...                                        ...      ...        ...
# 16705  https://cdn.sofifa.com/flags/gb-eng.png       53         70
# 16706      https://cdn.sofifa.com/flags/ro.png       53         63
# 16707      https://cdn.sofifa.com/flags/cn.png       47         60
# 16708      https://cdn.sofifa.com/flags/in.png       47         67
# 16709      https://cdn.sofifa.com/flags/it.png       28         38
#
#                         Club                                   Club Logo  ...  \
# 0          Manchester United      https://cdn.sofifa.com/teams/11/30.png  ...
# 1          FC Bayern München      https://cdn.sofifa.com/teams/21/30.png  ...
# 2         Atlético de Madrid     https://cdn.sofifa.com/teams/240/30.png  ...
# 3            Manchester City      https://cdn.sofifa.com/teams/10/30.png  ...
# 4                 Sevilla FC     https://cdn.sofifa.com/teams/481/30.png  ...
# ...                      ...                                         ...  ...
# 16705        Cheltenham Town    https://cdn.sofifa.com/teams/1936/30.png  ...
# 16706  FC Academica Clinceni  https://cdn.sofifa.com/teams/113391/30.png  ...
# 16707    Shanghai Shenhua FC  https://cdn.sofifa.com/teams/110955/30.png  ...
# 16708     ATK Mohun Bagan FC  https://cdn.sofifa.com/teams/113146/30.png  ...
# 16709                 Arezzo  https://cdn.sofifa.com/teams/110907/30.png  ...
#
#       SlidingTackle GKDiving  GKHandling GKKicking  GKPositioning  GKReflexes  \
# 0              65.0     12.0        14.0      15.0            8.0        14.0
# 1              77.0     13.0         8.0      15.0           11.0         9.0
# 2              38.0     27.0        25.0      31.0           33.0        37.0
# 3              53.0     15.0        13.0       5.0           10.0        13.0
# 4              82.0      8.0        14.0      13.0           13.0        14.0
# ...             ...      ...         ...       ...            ...         ...
# 16705          12.0     55.0        54.0      52.0           50.0        59.0
# 16706          12.0     57.0        52.0      53.0           48.0        58.0
# 16707           9.0     49.0        48.0      45.0           38.0        52.0
# 16708          13.0     49.0        41.0      39.0           45.0        49.0
# 16709           NaN      7.0         1.0      36.0            6.0         9.0
#
#        Best Position Best Overall Rating Release Clause DefensiveAwareness
# 0                CAM                88.0        €206.9M               72.0
# 1                 CM                87.0        €160.4M               74.0
# 2                 ST                88.0         €91.2M               42.0
# 3                 CM                91.0        €232.2M               68.0
# 4                 LB                84.0         €77.7M               80.0
# ...              ...                 ...            ...                ...
# 16705             GK                52.0          €238K                NaN
# 16706             GK                53.0          €279K                5.0
# 16707             GK                47.0          €223K               21.0
# 16708             GK                47.0          €259K                7.0
# 16709             ST                36.0            NaN                NaN
#
# [16710 rows x 65 columns]

# %%
# 데이터프레임 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16710 entries, 0 to 16709
# Data columns (total 65 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        16710 non-null  int64
#  1   Name                      16710 non-null  object
#  2   Age                       16710 non-null  int64
#  3   Photo                     16710 non-null  object
#  4   Nationality               16710 non-null  object
#  5   Flag                      16710 non-null  object
#  6   Overall                   16710 non-null  int64
#  7   Potential                 16710 non-null  int64
#  8   Club                      16446 non-null  object
#  9   Club Logo                 16710 non-null  object
#  10  Value                     16710 non-null  object
#  11  Wage                      16710 non-null  object
#  12  Special                   16710 non-null  int64
#  13  Preferred Foot            16710 non-null  object
#  14  International Reputation  16710 non-null  float64
#  15  Weak Foot                 16710 non-null  float64
#  16  Skill Moves               16710 non-null  float64
#  17  Work Rate                 16710 non-null  object
#  18  Body Type                 16681 non-null  object
#  19  Real Face                 16681 non-null  object
#  20  Position                  16684 non-null  object
#  21  Jersey Number             16684 non-null  float64
#  22  Joined                    15198 non-null  object
#  23  Loaned From               1132 non-null   object
#  24  Contract Valid Until      16359 non-null  object
#  25  Height                    16710 non-null  object
#  26  Weight                    16710 non-null  object
#  27  Crossing                  16710 non-null  float64
#  28  Finishing                 16710 non-null  float64
#  29  HeadingAccuracy           16710 non-null  float64
#  30  ShortPassing              16710 non-null  float64
#  31  Volleys                   16673 non-null  float64
#  32  Dribbling                 16710 non-null  float64
#  33  Curve                     16673 non-null  float64
#  34  FKAccuracy                16710 non-null  float64
#  35  LongPassing               16710 non-null  float64
#  36  BallControl               16710 non-null  float64
#  37  Acceleration              16710 non-null  float64
#  38  SprintSpeed               16710 non-null  float64
#  39  Agility                   16673 non-null  float64
#  40  Reactions                 16710 non-null  float64
#  41  Balance                   16673 non-null  float64
#  42  ShotPower                 16710 non-null  float64
#  43  Jumping                   16673 non-null  float64
#  44  Stamina                   16710 non-null  float64
#  45  Strength                  16710 non-null  float64
#  46  LongShots                 16710 non-null  float64
#  47  Aggression                16710 non-null  float64
#  48  Interceptions             16702 non-null  float64
#  49  Positioning               16702 non-null  float64
#  50  Vision                    16673 non-null  float64
#  51  Penalties                 16710 non-null  float64
#  52  Composure                 16459 non-null  float64
#  53  Marking                   892 non-null    float64
#  54  StandingTackle            16710 non-null  float64
#  55  SlidingTackle             16673 non-null  float64
#  56  GKDiving                  16710 non-null  float64
#  57  GKHandling                16710 non-null  float64
#  58  GKKicking                 16710 non-null  float64
#  59  GKPositioning             16710 non-null  float64
#  60  GKReflexes                16710 non-null  float64
#  61  Best Position             16710 non-null  object
#  62  Best Overall Rating       16710 non-null  float64
#  63  Release Clause            14961 non-null  object
#  64  DefensiveAwareness        15818 non-null  float64
# dtypes: float64(40), int64(5), object(20)
# memory usage: 8.3+ MB

# %%
# 포지션 예측을 위한 컬럼 확인
df[['Name','Position','Best Position']]
# Out:
#                   Name                     Position Best Position
# 0      Bruno Fernandes  <span class="pos pos18">CAM           CAM
# 1          L. Goretzka  <span class="pos pos11">LDM            CM
# 2            L. Suárez   <span class="pos pos24">RS            ST
# 3         K. De Bruyne  <span class="pos pos13">RCM            CM
# 4             M. Acuña    <span class="pos pos7">LB            LB
# ...                ...                          ...           ...
# 16705    18 L. Clayton  <span class="pos pos29">RES            GK
# 16706         �. Dobre  <span class="pos pos29">RES            GK
# 16707   21 Xue Qinghao  <span class="pos pos29">RES            GK
# 16708        A. Shaikh  <span class="pos pos28">SUB            GK
# 16709    07 A. Censori  <span class="pos pos28">SUB            ST
#
# [16710 rows x 3 columns]

# %%
# 포지션 확인
print(df['Best Position'].unique(), '포지션 개수', len(df['Best Position'].unique()), '개')
# Out:
# ['CAM' 'CM' 'ST' 'LB' 'CDM' 'CB' 'RB' 'LM' 'RW' 'LW' 'CF' 'LWB' 'RM' 'RWB'
#  'GK'] 포지션 개수 15 개

# %%
# 포지션별 카운트
plt.figure(figsize = (6,3), dpi = 150)
sns.countplot(x = df['Best Position'], data = df)
plt.show()

# %% [markdown]
# ### 레이블 인코딩

# %%
# 데이터 레이블 인코딩
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder() # 레이블 인코더는 정수 인덱스로 바꾸어줍니다. 나중에 One-hot Encoding과 비교해서 참고해보시면 좋아요.

# %%
# 정답 레이블 인코딩
y = encoder.fit_transform(df['Best Position']); y # 정답 레이블을 정수 인덱스로 반환하였습니다.
# 다시 정수를 문자열로 알아보고 싶다면 encoder.inverse_transform(y)를 실행하시면 됩니다.
# Out:
# array([ 0,  4, 14, ...,  5,  5, 14])

# %% [markdown]
# ### 특성(Feature) 선택

# %%
# 컬럼 인덱스 확인하기
for i, v in enumerate(df.columns):
    print(i, v)
# Out:
# 0 ID
# 1 Name
# 2 Age
# 3 Photo
# 4 Nationality
# 5 Flag
# 6 Overall
# 7 Potential
# 8 Club
# 9 Club Logo
# 10 Value
# 11 Wage
# 12 Special
# 13 Preferred Foot
# 14 International Reputation
# 15 Weak Foot
# 16 Skill Moves
# 17 Work Rate
# 18 Body Type
# 19 Real Face
# 20 Position
# 21 Jersey Number
# 22 Joined
# 23 Loaned From
# 24 Contract Valid Until
# 25 Height
# 26 Weight
# 27 Crossing
# 28 Finishing
# 29 HeadingAccuracy
# 30 ShortPassing
# 31 Volleys
# 32 Dribbling
# 33 Curve
# 34 FKAccuracy
# 35 LongPassing
# 36 BallControl
# 37 Acceleration
# 38 SprintSpeed
# 39 Agility
# 40 Reactions
# 41 Balance
# 42 ShotPower
# 43 Jumping
# 44 Stamina
# 45 Strength
# 46 LongShots
# 47 Aggression
# 48 Interceptions
# 49 Positioning
# 50 Vision
# 51 Penalties
# 52 Composure
# 53 Marking
# 54 StandingTackle
# 55 SlidingTackle
# 56 GKDiving
# 57 GKHandling
# 58 GKKicking
# 59 GKPositioning
# 60 GKReflexes
# 61 Best Position
# 62 Best Overall Rating
# 63 Release Clause
# 64 DefensiveAwareness

# %%
x = df.iloc[:,27:61]; x
# Out:
#        Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0          87.0       83.0             64.0          91.0     87.0       83.0
# 1          75.0       82.0             86.0          86.0     69.0       84.0
# 2          80.0       93.0             84.0          83.0     90.0       83.0
# 3          94.0       82.0             55.0          94.0     82.0       88.0
# 4          87.0       66.0             58.0          82.0     68.0       87.0
# ...         ...        ...              ...           ...      ...        ...
# 16705      12.0        5.0             13.0          18.0      7.0       12.0
# 16706      13.0        7.0             10.0          17.0      7.0        6.0
# 16707      12.0        9.0             14.0          15.0      6.0        8.0
# 16708      13.0        8.0             10.0          22.0      8.0       10.0
# 16709      34.0       39.0             29.0          32.0      NaN       29.0
#
#        Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0       87.0        87.0         88.0         87.0  ...       91.0       87.0
# 1       76.0        75.0         84.0         87.0  ...       60.0       82.0
# 2       86.0        82.0         77.0         86.0  ...       83.0       87.0
# 3       85.0        83.0         93.0         91.0  ...       83.0       89.0
# 4       88.0        75.0         78.0         88.0  ...       76.0       87.0
# ...      ...         ...          ...          ...  ...        ...        ...
# 16705   11.0        13.0         19.0         10.0  ...       18.0       37.0
# 16706   11.0        13.0         28.0         17.0  ...       12.0       29.0
# 16707   12.0        13.0         14.0         12.0  ...       15.0       17.0
# 16708   11.0        13.0         18.0         13.0  ...       19.0       23.0
# 16709    NaN        11.0         36.0         34.0  ...       11.0        NaN
#
#        Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0          NaN            73.0           65.0      12.0        14.0
# 1          NaN            85.0           77.0      13.0         8.0
# 2          NaN            45.0           38.0      27.0        25.0
# 3          NaN            65.0           53.0      15.0        13.0
# 4          NaN            84.0           82.0       8.0        14.0
# ...        ...             ...            ...       ...         ...
# 16705      5.0            11.0           12.0      55.0        54.0
# 16706      NaN            13.0           12.0      57.0        52.0
# 16707      NaN            11.0            9.0      49.0        48.0
# 16708      NaN            14.0           13.0      49.0        41.0
# 16709     15.0            16.0            NaN       7.0         1.0
#
#        GKKicking  GKPositioning  GKReflexes
# 0           15.0            8.0        14.0
# 1           15.0           11.0         9.0
# 2           31.0           33.0        37.0
# 3            5.0           10.0        13.0
# 4           13.0           13.0        14.0
# ...          ...            ...         ...
# 16705       52.0           50.0        59.0
# 16706       53.0           48.0        58.0
# 16707       45.0           38.0        52.0
# 16708       39.0           45.0        49.0
# 16709       36.0            6.0         9.0
#
# [16710 rows x 34 columns]

# %%
# 결측치 개수 확인
x.isnull().sum()
# Out:
# Crossing               0
# Finishing              0
# HeadingAccuracy        0
# ShortPassing           0
# Volleys               37
# Dribbling              0
# Curve                 37
# FKAccuracy             0
# LongPassing            0
# BallControl            0
# Acceleration           0
# SprintSpeed            0
# Agility               37
# Reactions              0
# Balance               37
# ShotPower              0
# Jumping               37
# Stamina                0
# Strength               0
# LongShots              0
# Aggression             0
# Interceptions          8
# Positioning            8
# Vision                37
# Penalties              0
# Composure            251
# Marking            15818
# StandingTackle         0
# SlidingTackle         37
# GKDiving               0
# GKHandling             0
# GKKicking              0
# GKPositioning          0
# GKReflexes             0
# dtype: int64

# %%
x.drop('Marking', axis = 1, inplace = True)

# %%
# 컬럼 제거
x.drop('Marking', axis = 1, inplace = True)

# %% [markdown]
# ### 결측 데이터 보간

# %%
# 결측 데이터 확인
df[df['Volleys'].isnull()]
# Out:
#            ID               Name  Age  \
# 7976   177176  09 H. de Noteboom   32
# 9695     5003            08 Cafu   37
# 10673    5680     08 P. Kluivert   30
# 10700    4738       08 A. Recoba   31
# 10993    5589            09 Figo   35
# 11062   23330       10 M. Bordon   33
# 11881    4233        08 C. Reyna   33
# 12216    1615       08 L. Thuram   35
# 12233    1249       08 E. Chiesa   36
# 12247    4767         10 Emerson   33
# 12756  140957       10 O. Husyev   26
# 12939   13128   10 A. Shevchenko   32
# 13042   10953     10 M. Gallardo   33
# 13351    1183    10 F. Cannavaro   35
# 13387    5736         07 P. Cocu   35
# 13523    1109      09 P. Maldini   40
# 13928  137823        09 Pedrinho   31
# 14038    1845     08 O. Solskjær   34
# 14182   17272       09 K. Fadiga   33
# 14248   10704       10 R. Makaay   34
# 14415  110153          07 Romero   35
# 14648   48016    10 S. Coulibaly   31
# 14846   13850       10 Sun Jihai   31
# 14875  146467          09 Miguel   30
# 15079  156639   08 R. Livramento   32
# 15146   46821         10 Tristán   33
# 15184  183375      09 Fábio Paim   20
# 15282    3127           07 Silva   30
# 15351    4174         07 P. Sarr   28
# 15492     488         08 O. Kahn   38
# 15638    4373     07 S. Valakari   33
# 15787  161659          07 Danilo   24
# 15794  164945     07 Nuno Mendes   28
# 15844  150597      09 J. Moukoko   23
# 16155    4703     08 M. Ballotta   43
# 16572   19334   10 I. Baraclough   38
# 16709  178453      07 A. Censori   17
#
#                                                   Photo    Nationality  \
# 7976   https://cdn.sofifa.com/players/177/176/09_60.png    Netherlands
# 9695   https://cdn.sofifa.com/players/005/003/08_60.png         Brazil
# 10673  https://cdn.sofifa.com/players/005/680/08_60.png    Netherlands
# 10700  https://cdn.sofifa.com/players/004/738/08_60.png        Uruguay
# 10993  https://cdn.sofifa.com/players/005/589/09_60.png       Portugal
# 11062  https://cdn.sofifa.com/players/023/330/10_60.png         Brazil
# 11881  https://cdn.sofifa.com/players/004/233/08_60.png  United States
# 12216  https://cdn.sofifa.com/players/001/615/08_60.png         France
# 12233  https://cdn.sofifa.com/players/001/249/08_60.png          Italy
# 12247  https://cdn.sofifa.com/players/004/767/10_60.png         Brazil
# 12756  https://cdn.sofifa.com/players/140/957/10_60.png        Ukraine
# 12939  https://cdn.sofifa.com/players/013/128/10_60.png        Ukraine
# 13042  https://cdn.sofifa.com/players/010/953/10_60.png      Argentina
# 13351  https://cdn.sofifa.com/players/001/183/10_60.png          Italy
# 13387  https://cdn.sofifa.com/players/005/736/07_60.png    Netherlands
# 13523  https://cdn.sofifa.com/players/001/109/09_60.png          Italy
# 13928  https://cdn.sofifa.com/players/137/823/09_60.png         Brazil
# 14038  https://cdn.sofifa.com/players/001/845/08_60.png         Norway
# 14182  https://cdn.sofifa.com/players/017/272/09_60.png        Senegal
# 14248  https://cdn.sofifa.com/players/010/704/10_60.png    Netherlands
# 14415  https://cdn.sofifa.com/players/110/153/07_60.png          Spain
# 14648  https://cdn.sofifa.com/players/048/016/10_60.png           Mali
# 14846  https://cdn.sofifa.com/players/013/850/10_60.png       China PR
# 14875  https://cdn.sofifa.com/players/146/467/09_60.png          Spain
# 15079  https://cdn.sofifa.com/players/156/639/08_60.png         France
# 15146  https://cdn.sofifa.com/players/046/821/10_60.png          Spain
# 15184  https://cdn.sofifa.com/players/183/375/09_60.png       Portugal
# 15282  https://cdn.sofifa.com/players/003/127/07_60.png         Brazil
# 15351  https://cdn.sofifa.com/players/004/174/07_60.png        Senegal
# 15492  https://cdn.sofifa.com/players/000/488/08_60.png        Germany
# 15638  https://cdn.sofifa.com/players/004/373/07_60.png        Finland
# 15787  https://cdn.sofifa.com/players/161/659/07_60.png         Brazil
# 15794  https://cdn.sofifa.com/players/164/945/07_60.png       Portugal
# 15844  https://cdn.sofifa.com/players/150/597/09_60.png       Congo DR
# 16155  https://cdn.sofifa.com/players/004/703/08_60.png          Italy
# 16572  https://cdn.sofifa.com/players/019/334/10_60.png        England
# 16709  https://cdn.sofifa.com/players/178/453/07_60.png          Italy
#
#                                           Flag  Overall  Potential  \
# 7976       https://cdn.sofifa.com/flags/nl.png       87         90
# 9695       https://cdn.sofifa.com/flags/br.png       83         88
# 10673      https://cdn.sofifa.com/flags/nl.png       81         81
# 10700      https://cdn.sofifa.com/flags/uy.png       86         87
# 10993      https://cdn.sofifa.com/flags/pt.png       78         86
# 11062      https://cdn.sofifa.com/flags/br.png       82         84
# 11881      https://cdn.sofifa.com/flags/us.png       76         80
# 12216      https://cdn.sofifa.com/flags/fr.png       83         87
# 12233      https://cdn.sofifa.com/flags/it.png       79         83
# 12247      https://cdn.sofifa.com/flags/br.png       75         85
# 12756      https://cdn.sofifa.com/flags/ua.png       78         87
# 12939      https://cdn.sofifa.com/flags/ua.png       77         85
# 13042      https://cdn.sofifa.com/flags/ar.png       74         87
# 13351      https://cdn.sofifa.com/flags/it.png       82         89
# 13387      https://cdn.sofifa.com/flags/nl.png       87         88
# 13523      https://cdn.sofifa.com/flags/it.png       77         89
# 13928      https://cdn.sofifa.com/flags/br.png       72         80
# 14038      https://cdn.sofifa.com/flags/no.png       75         83
# 14182      https://cdn.sofifa.com/flags/sn.png       72         78
# 14248      https://cdn.sofifa.com/flags/nl.png       72         88
# 14415      https://cdn.sofifa.com/flags/es.png       78         84
# 14648      https://cdn.sofifa.com/flags/ml.png       66         74
# 14846      https://cdn.sofifa.com/flags/cn.png       64         75
# 14875      https://cdn.sofifa.com/flags/es.png       67         71
# 15079      https://cdn.sofifa.com/flags/fr.png       62         62
# 15146      https://cdn.sofifa.com/flags/es.png       66         81
# 15184      https://cdn.sofifa.com/flags/pt.png       70         78
# 15282      https://cdn.sofifa.com/flags/br.png       71         70
# 15351      https://cdn.sofifa.com/flags/sn.png       65         70
# 15492      https://cdn.sofifa.com/flags/de.png       87         90
# 15638      https://cdn.sofifa.com/flags/fi.png       66         67
# 15787      https://cdn.sofifa.com/flags/br.png       64         67
# 15794      https://cdn.sofifa.com/flags/pt.png       71         70
# 15844      https://cdn.sofifa.com/flags/cd.png       54         62
# 16155      https://cdn.sofifa.com/flags/it.png       65         66
# 16572  https://cdn.sofifa.com/flags/gb-eng.png       44         65
# 16709      https://cdn.sofifa.com/flags/it.png       28         38
#
#                               Club  \
# 7976                        111648
# 9695                      AC Milan
# 10673                   LOSC Lille
# 10700                  Torino F.C.
# 10993                        Inter
# 11062                FC Schalke 04
# 11881           New York Red Bulls
# 12216                 FC Barcelona
# 12233                        Siena
# 12247                          NaN
# 12756                          NaN
# 12939                          NaN
# 13042                  River Plate
# 13351                     Juventus
# 13387                          PSV
# 13523                     AC Milan
# 13928                  Figueirense
# 14038            Manchester United
# 14182                          NaN
# 14248                    Feyenoord
# 14415          Real Betis Balompié
# 14648                FSV Frankfurt
# 14846                          NaN
# 14875                     Elche CF
# 15079     FC Libourne-Saint-Seurin
# 15146                     Cádiz CF
# 15184                      Chelsea
# 15282      Suwon Samsung Bluewings
# 15351            Stade Brestois 29
# 15492            FC Bayern München
# 15638                    FC Dallas
# 15787  Gallos Blancos de Querétaro
# 15794         US Créteil-Lusitanos
# 15844                          NaN
# 16155                        Lazio
# 16572                          NaN
# 16709                       Arezzo
#
#                                         Club Logo  ... SlidingTackle GKDiving  \
# 7976   https://cdn.sofifa.com/teams/111648/30.png  ...           NaN      7.0
# 9695       https://cdn.sofifa.com/teams/47/30.png  ...           NaN     13.0
# 10673      https://cdn.sofifa.com/teams/65/30.png  ...           NaN      9.0
# 10700      https://cdn.sofifa.com/teams/54/30.png  ...           NaN      6.0
# 10993      https://cdn.sofifa.com/teams/44/30.png  ...           NaN      6.0
# 11062      https://cdn.sofifa.com/teams/34/30.png  ...           NaN      6.0
# 11881     https://cdn.sofifa.com/teams/689/30.png  ...           NaN      8.0
# 12216     https://cdn.sofifa.com/teams/241/30.png  ...           NaN      8.0
# 12233    https://cdn.sofifa.com/teams/1838/30.png  ...           NaN      8.0
# 12247         https://cdn.sofifa.com/flags/br.png  ...           NaN      7.0
# 12756         https://cdn.sofifa.com/flags/ua.png  ...           NaN      9.0
# 12939         https://cdn.sofifa.com/flags/ua.png  ...           NaN      9.0
# 13042    https://cdn.sofifa.com/teams/1876/30.png  ...           NaN     10.0
# 13351      https://cdn.sofifa.com/teams/45/30.png  ...           NaN      5.0
# 13387     https://cdn.sofifa.com/teams/247/30.png  ...           NaN     10.0
# 13523      https://cdn.sofifa.com/teams/47/30.png  ...           NaN      5.0
# 13928  https://cdn.sofifa.com/teams/111045/30.png  ...           NaN      3.0
# 14038      https://cdn.sofifa.com/teams/11/30.png  ...           NaN     10.0
# 14182         https://cdn.sofifa.com/flags/sn.png  ...           NaN      8.0
# 14248     https://cdn.sofifa.com/teams/246/30.png  ...           NaN      4.0
# 14415     https://cdn.sofifa.com/teams/449/30.png  ...           NaN      7.0
# 14648  https://cdn.sofifa.com/teams/110596/30.png  ...           NaN     13.0
# 14846         https://cdn.sofifa.com/flags/cn.png  ...           NaN     10.0
# 14875     https://cdn.sofifa.com/teams/468/30.png  ...           NaN      8.0
# 15079  https://cdn.sofifa.com/teams/110318/30.png  ...           NaN      8.0
# 15146    https://cdn.sofifa.com/teams/1968/30.png  ...           NaN      9.0
# 15184       https://cdn.sofifa.com/teams/5/30.png  ...           NaN      9.0
# 15282     https://cdn.sofifa.com/teams/983/30.png  ...           NaN      8.0
# 15351     https://cdn.sofifa.com/teams/378/30.png  ...           NaN      9.0
# 15492      https://cdn.sofifa.com/teams/21/30.png  ...           NaN     83.0
# 15638     https://cdn.sofifa.com/teams/695/30.png  ...           NaN      6.0
# 15787  https://cdn.sofifa.com/teams/110150/30.png  ...           NaN     11.0
# 15794    https://cdn.sofifa.com/teams/1812/30.png  ...           NaN     11.0
# 15844         https://cdn.sofifa.com/flags/cd.png  ...           NaN      8.0
# 16155      https://cdn.sofifa.com/teams/46/30.png  ...           NaN     65.0
# 16572     https://cdn.sofifa.com/flags/gb-eng.png  ...           NaN      5.0
# 16709  https://cdn.sofifa.com/teams/110907/30.png  ...           NaN      7.0
#
#        GKHandling GKKicking  GKPositioning  GKReflexes  Best Position  \
# 7976         20.0      55.0           20.0        20.0             ST
# 9695         22.0      59.0           22.0        22.0             CF
# 10673        22.0      68.0           22.0        22.0             ST
# 10700        22.0      66.0           22.0        22.0             CF
# 10993        22.0      76.0           22.0        22.0             CF
# 11062        21.0      72.0           21.0        21.0             CB
# 11881        21.0      74.0           21.0        21.0             CM
# 12216        21.0      55.0           21.0        21.0             CB
# 12233        21.0      52.0           21.0        21.0             ST
# 12247        22.0      74.0           22.0        22.0            CDM
# 12756        23.0      83.0           23.0        23.0             CF
# 12939        23.0      52.0           23.0        23.0             ST
# 13042        23.0      74.0           23.0        23.0            CAM
# 13351        21.0      74.0           21.0        21.0             CB
# 13387         7.0      87.0            5.0        10.0             CM
# 13523        21.0      70.0           21.0        21.0             CB
# 13928        22.0      65.0           22.0        22.0             CF
# 14038        21.0      54.0           21.0        21.0             ST
# 14182        20.0      76.0           20.0        20.0             CF
# 14248        23.0      51.0           23.0        23.0             ST
# 14415        10.0      73.0            8.0         9.0             CB
# 14648        20.0      63.0           20.0        20.0            CAM
# 14846        23.0      47.0           23.0        23.0             CF
# 14875        24.0      42.0           24.0        24.0             ST
# 15079        20.0      54.0           20.0        20.0             RM
# 15146        25.0      46.0           25.0        25.0             ST
# 15184        21.0      53.0           21.0        21.0             CF
# 15282        13.0      51.0           12.0        10.0             ST
# 15351        12.0      68.0            8.0        11.0            CDM
# 15492        88.0      62.0           92.0        83.0             GK
# 15638         3.0      53.0            6.0         3.0            CDM
# 15787         6.0      57.0           15.0        12.0             ST
# 15794        12.0      26.0           13.0        13.0             CB
# 15844        25.0      40.0           25.0        25.0             ST
# 16155        69.0      77.0           73.0        68.0             GK
# 16572        20.0      46.0           20.0        20.0             CM
# 16709         1.0      36.0            6.0         9.0             ST
#
#       Best Overall Rating Release Clause DefensiveAwareness
# 7976                 89.0            NaN                NaN
# 9695                 86.0            NaN                NaN
# 10673                81.0            NaN                NaN
# 10700                86.0            NaN                NaN
# 10993                81.0            NaN                NaN
# 11062                83.0            NaN                NaN
# 11881                77.0            NaN                NaN
# 12216                83.0            NaN                NaN
# 12233                79.0            NaN                NaN
# 12247                75.0            NaN                NaN
# 12756                79.0            NaN                NaN
# 12939                77.0            NaN                NaN
# 13042                75.0            NaN                NaN
# 13351                82.0            NaN                NaN
# 13387                87.0            NaN                NaN
# 13523                78.0            NaN                NaN
# 13928                74.0            NaN                NaN
# 14038                75.0            NaN                NaN
# 14182                73.0            NaN                NaN
# 14248                73.0            NaN                NaN
# 14415                78.0            NaN                NaN
# 14648                72.0            NaN                NaN
# 14846                66.0            NaN                NaN
# 14875                64.0            NaN                NaN
# 15079                62.0            NaN                NaN
# 15146                71.0            NaN                NaN
# 15184                70.0            NaN                NaN
# 15282                71.0            NaN                NaN
# 15351                67.0            NaN                NaN
# 15492                87.0            NaN                NaN
# 15638                67.0            NaN                NaN
# 15787                64.0            NaN                NaN
# 15794                71.0            NaN                NaN
# 15844                57.0            NaN                NaN
# 16155                65.0            NaN                NaN
# 16572                46.0            NaN                NaN
# 16709                36.0            NaN                NaN
#
# [37 rows x 65 columns]

# %%
# 결측 데이터 보간
x.interpolate(axis = 1, inplace = True)

# %%
x.isnull().sum()
# Out:
# Crossing           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# StandingTackle     0
# SlidingTackle      0
# GKDiving           0
# GKHandling         0
# GKKicking          0
# GKPositioning      0
# GKReflexes         0
# dtype: int64

# %%
# (참고) k-NN으로 보간
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3)
# x = imputer.fit_transform(x)

# %% [markdown]
# ## 포지션 분류

# %% [markdown]
# ### 학습-훈련 데이터셋 구축
# 사이킷런에서 제공하는 `train_test_split`을 이용하면 편리하게 구분할 수 있습니다.<br>
# test_size에는 비율만 입력하면 임의로 학습 데이터와 훈련 데이터를 분리해줍니다.<br>
# 직접 30%를 분리해도 괜찮지만 랜덤하게 샘플링하려면 이 방법이 훨씬 편리합니다.<br>
# 테스트셋의 사이즈는 보통 20~30%로 설정합니다.<br>
# 학습에 데이터가 부족하지는 않기 때문에 30%로 설정하였습니다.

# %%
# 학습-훈련 데이터셋 분리
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 319)

# %%
# k-NN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

neigh = KNeighborsClassifier(n_neighbors=100) # n_neighbors가 자신을 결정할 이웃의 수입니다. 중요한 하이퍼 파라미터입니다.
neigh.fit(x_train, y_train)

y_pred = neigh.predict(x_test)

acc = accuracy_score(y_test,y_pred) # 정확도
print('k-NN 모델의 정확도:', '%.4f'%acc)
# Out:
# k-NN 모델의 정확도: 0.6866

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# 데이터 정규화와 파이프 라인 설계
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('knn', KNeighborsClassifier(n_neighbors=100))
                     ])
pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)
acc = accuracy_score(y_test, y_pred)
print('정규화된 k-NN 모델의 정확도:', '%.4f'%acc)
# Out:
# 정규화된 k-NN 모델의 정확도: 0.6808

# %%
from sklearn.tree import DecisionTreeClassifier

# 의사 결정 나무
dt = DecisionTreeClassifier(max_depth = 10)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)
acc = accuracy_score(y_test,y_pred)
print('Decision Tree 모델의 정확도:', '%.4f'%acc)
# Out:
# Decision Tree 모델의 정확도: 0.6379

# %%
# 의사 결정 나무 - 정규화
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('dt', DecisionTreeClassifier(max_depth = 10))
                     ])
pipeline.fit(x_train,y_train)
y_pred = dt.predict(x_test)
acc = accuracy_score(y_test,y_pred)
print('Decision Tree 모델의 정확도:', '%.4f'%acc)
# Out:
# Decision Tree 모델의 정확도: 0.6379

# %%
# 랜덤 포레스트
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_depth = 15, random_state = 319)

rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
acc = accuracy_score(y_test, y_pred)
print('Ramdom Forest 모델의 정확도:', '%.4f'%acc)
# Out:
# Ramdom Forest 모델의 정확도: 0.7056

# %%
# 랜덤 포레스트 - 정규화
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('rf', RandomForestClassifier(max_depth = 15, random_state = 319))
                     ])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)
acc = accuracy_score(y_test, y_pred)
print('Ramdom Forest 모델의 정확도:', '%.4f'%acc)
# Out:
# Ramdom Forest 모델의 정확도: 0.7066

# %%
# XGBoost
import xgboost
from xgboost import XGBClassifier

xgb = XGBClassifier(max_depth=15)
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)
acc = accuracy_score(y_test, y_pred)
print('XGBoost 모델의 정확도:', '%.4f'%acc)
# Out:
# XGBoost 모델의 정확도: 0.7183

# %%
# Support Vector Machine Classifier
from sklearn.svm import SVC
svc = SVC(C =100)
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
acc = accuracy_score(y_test, y_pred)
print('Support Vector Machine 모델의 정확도:', '%.4f'%acc)
# Out:
# Support Vector Machine 모델의 정확도: 0.7393

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('lr', LogisticRegression(solver = 'lbfgs', max_iter = 1000))
                     ])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)
acc = accuracy_score(y_test, y_pred)
print('Logistic Regression 모델의 정확도:', '%.4f'%acc)
# Out:
# Logistic Regression 모델의 정확도: 0.7578

# %%
# Logistic Regression의 계수
matrix = pd.DataFrame(pipeline['lr'].coef_, columns = x_train.columns, index = encoder.inverse_transform(range(15)))

plt.figure(figsize = (13,3), dpi = 150)
sns.heatmap(matrix, cmap = 'vlag')
plt.show()

# %%
y_test_label = encoder.inverse_transform(y_test)
y_pred_label = encoder.inverse_transform(y_pred)

# %%
# 실제 값과 예측값 비교
pred = pd.DataFrame(zip(y_test_label, y_pred_label), columns = ['test', 'pred'])
pred
# Out:
#      test pred
# 0      RW   ST
# 1     CAM  CAM
# 2      RB   LB
# 3      RB   RB
# 4     CAM  CAM
# ...   ...  ...
# 5008   ST   ST
# 5009   LW   RW
# 5010   ST   ST
# 5011   CB   CB
# 5012   CM   CM
#
# [5013 rows x 2 columns]

# %%
error = pred[pred['test'] != pred['pred']].copy()

# %%
# 피벗테이블을 통해 히트맵 시각화를 위한 표 만들기
error['count'] = 1 # 이렇게 하면 count를 모두 1로 지정할 수 있습니다.
error = error.pivot_table(values = 'count', columns = 'test', index = 'pred', aggfunc = 'sum').copy(); error
# Out:
# test   CAM    CB   CDM   CF    CM    LB     LM    LW   LWB    RB    RM    RW  \
# pred
# CAM    NaN   NaN   1.0  9.0  31.0   NaN   51.0  18.0   NaN   NaN  67.0  27.0
# CB     NaN   NaN  26.0  NaN   1.0  10.0    NaN   NaN   NaN  12.0   NaN   NaN
# CDM    3.0  21.0   NaN  NaN  39.0   8.0    2.0   NaN   1.0   6.0   NaN   NaN
# CF     1.0   NaN   NaN  NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN   NaN
# CM    30.0   1.0  33.0  NaN   NaN   NaN    1.0   NaN   1.0   3.0   8.0   NaN
# LB     NaN   4.0   4.0  1.0   5.0   NaN    5.0   NaN  38.0  76.0   4.0   1.0
# LM     5.0   NaN   NaN  NaN   NaN   2.0    NaN   8.0   1.0   1.0  22.0   6.0
# LW     NaN   NaN   NaN  NaN   NaN   NaN    1.0   NaN   NaN   NaN   NaN   1.0
# LWB    NaN   NaN   NaN  NaN   1.0   8.0    2.0   NaN   NaN   3.0   3.0   NaN
# RB     NaN  15.0   9.0  NaN   1.0  94.0    NaN   NaN  13.0   NaN   3.0   NaN
# RM    23.0   NaN   NaN  2.0   2.0  12.0  127.0  15.0   3.0  12.0   NaN  37.0
# RW     3.0   NaN   NaN  NaN   NaN   NaN   10.0  14.0   NaN   NaN  15.0   NaN
# RWB    NaN   NaN   NaN  NaN   NaN   3.0    NaN   NaN   8.0  11.0   3.0   NaN
# ST     9.0   1.0   NaN  7.0   1.0   NaN    8.0   7.0   NaN   NaN  11.0   8.0
#
# test   RWB   ST
# pred
# CAM    1.0  4.0
# CB     2.0  1.0
# CDM    6.0  NaN
# CF     NaN  1.0
# CM     3.0  1.0
# LB    25.0  NaN
# LM     NaN  NaN
# LW     NaN  1.0
# LWB    9.0  NaN
# RB    40.0  NaN
# RM     5.0  9.0
# RW     NaN  6.0
# RWB    NaN  NaN
# ST     NaN  NaN

# %%
# 잘못 분류된 레이블 히트맵 시각화
plt.figure(figsize = (7,3), dpi = 150)
sns.heatmap(error, cmap = 'flare')
plt.show()

# %%
def error_heatmap(y_test,y_pred):
    y_test_label = encoder.inverse_transform(y_test)
    y_pred_label = encoder.inverse_transform(y_pred)
    pred = pd.DataFrame(zip(y_test_label, y_pred_label), columns = ['test', 'pred'])

    error = pred[pred['test'] != pred['pred']].copy()
    error['count'] = 1
    error = error.pivot_table(values = 'count', columns = 'test', index = 'pred', aggfunc = 'sum').copy()

    plt.figure(figsize = (7,3), dpi = 150)
    sns.heatmap(error, cmap = 'flare')
    plt.show()

# %% [markdown]
# ### 피처 엔지니어링
# 특성 공학이라고도 불리는 피처 엔지니어링(Feature Engineering)은 말 그대로 성능을 개선하기 위해 특성을 조작하는 것입니다.<br>
# 방법은 정말 다양한데, 지난 시간에 학습한 PCA를 활용하여 **Feature Extraction**하는 방법도 있고,<br>
# 특성의 일부만 활용하여 **Feature Selection**하는 방법도 있습니다.<br>
# <br>
# 히트맵을 보니 Right와 Left를 잘 구분하지 못하는 것 같습니다.<br>
# 그렇다면 자주 사용하는 발 정보를 넣어주면 성능이 오르지 않을까요?<br>
# 이번 시간에는 간단하게 `Preferred Foot` 정보를 데이터셋에 추가해보도록 하겠습니다.

# %%
# Preferred Foot 값 확인
df['Preferred Foot'].unique()
# Out:
# array(['Right', 'Left'], dtype=object)

# %%
# 선호하는 발 특성 추가
x = pd.concat([x,df['Preferred Foot']], axis = 1)

# %%
# 선호하는 발 정수 인덱싱
x['Preferred Foot'] = x['Preferred Foot'].map(lambda foot : 1 if foot == 'Right' else 0)

# %%
# 새로운 결과 확인
import time

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 319)

pipeline = Pipeline([('scaler', StandardScaler()),
                     ('lr', LogisticRegression(solver = 'lbfgs', max_iter = 1000))
                     ])

start = time.time()
pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)

print(f"{time.time()-start:.4f} 초 소요")
acc = accuracy_score(y_test, y_pred)
print('Logistic Regression 모델의 정확도:', '%.4f'%acc)
# Out:
# 7.4366 초 소요
# Logistic Regression 모델의 정확도: 0.8129

# %% [markdown]
# ### 하이퍼 파라미터 튜닝
# 앞서 `k-NN`의 k나 `DecisionTree`의 max_depth와 같은 값은 모델의 결과에 큰 영향을 미칠 수 있는 중요한 하이퍼 파라미터입니다.<br>
# 최적의 하이퍼 파라미터를 찾기 위한 방법론들이 있지만, 가장 좋은 방법은 직접 다 넣어보는 것입니다!<br>
# 쉽게 하이퍼 파라미터에 따른 결과를 비교해볼 수 있도록 사이킷런에서는 `GridSearch`를 제공하고 있습니다.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 319)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV

# 모델 파이프라인 설정
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('lr', LogisticRegression(max_iter = 1000))
                     ])

# %%
# 하이퍼 파라미터 설정
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
c_values = [100, 10, 1.0, 0.1, 0.01]

# %%
# GridSearch 적용
grid = dict(lr__solver = solvers, lr__C = c_values)

# %%
# CrossValidation 설정
cv = StratifiedKFold(n_splits=3, random_state = 319, shuffle = True)

# %%
# GridSearchCV 학습
grid_search = GridSearchCV(estimator=pipeline, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy', error_score=0)
grid_result = grid_search.fit(x_train, y_train)

# %%
# 결과 요약
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.799094 using {'lr__C': 1.0, 'lr__solver': 'lbfgs'}
# 0.797897 (0.000209) with: {'lr__C': 100, 'lr__solver': 'newton-cg'}
# 0.797897 (0.000209) with: {'lr__C': 100, 'lr__solver': 'lbfgs'}
# 0.759255 (0.002668) with: {'lr__C': 100, 'lr__solver': 'liblinear'}
# 0.797726 (0.000121) with: {'lr__C': 100, 'lr__solver': 'sag'}
# 0.797726 (0.000242) with: {'lr__C': 100, 'lr__solver': 'saga'}
# 0.798239 (0.000320) with: {'lr__C': 10, 'lr__solver': 'newton-cg'}
# 0.798324 (0.000242) with: {'lr__C': 10, 'lr__solver': 'lbfgs'}
# 0.759255 (0.002585) with: {'lr__C': 10, 'lr__solver': 'liblinear'}
# 0.798324 (0.000121) with: {'lr__C': 10, 'lr__solver': 'sag'}
# 0.798068 (0.000436) with: {'lr__C': 10, 'lr__solver': 'saga'}
# 0.799008 (0.002098) with: {'lr__C': 1.0, 'lr__solver': 'newton-cg'}
# 0.799094 (0.002200) with: {'lr__C': 1.0, 'lr__solver': 'lbfgs'}
# 0.758913 (0.002770) with: {'lr__C': 1.0, 'lr__solver': 'liblinear'}
# 0.798923 (0.002304) with: {'lr__C': 1.0, 'lr__solver': 'sag'}
# 0.798923 (0.002304) with: {'lr__C': 1.0, 'lr__solver': 'saga'}
# 0.788835 (0.003481) with: {'lr__C': 0.1, 'lr__solver': 'newton-cg'}
# 0.789006 (0.003385) with: {'lr__C': 0.1, 'lr__solver': 'lbfgs'}
# 0.747115 (0.004012) with: {'lr__C': 0.1, 'lr__solver': 'liblinear'}
# 0.788920 (0.003498) with: {'lr__C': 0.1, 'lr__solver': 'sag'}
# 0.788835 (0.003481) with: {'lr__C': 0.1, 'lr__solver': 'saga'}
# 0.754894 (0.004930) with: {'lr__C': 0.01, 'lr__solver': 'newton-cg'}
# 0.754723 (0.005148) with: {'lr__C': 0.01, 'lr__solver': 'lbfgs'}
# 0.706762 (0.005767) with: {'lr__C': 0.01, 'lr__solver': 'liblinear'}
# 0.754894 (0.004930) with: {'lr__C': 0.01, 'lr__solver': 'sag'}
# 0.754809 (0.005039) with: {'lr__C': 0.01, 'lr__solver': 'saga'}

# %%
# 최적의 하이퍼 파라미터 설정 후 학습
start = time.time()
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('lr', LogisticRegression(solver = 'newton-cg', C = 100))
                     ])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)

print(f"{time.time()-start:.4f} 초 소요")
acc = accuracy_score(y_test, y_pred)
print('Logistic Regression 모델의 정확도:', '%.4f'%acc)
# Out:
# 47.3635 초 소요
# Logistic Regression 모델의 정확도: 0.8139

# %%
error_heatmap(y_test, y_pred)

# %%
rb_df = df[df['Best Position'] == 'RB'].iloc[:,27:61].copy()

# %%
rwb_df = df[df['Best Position'] == 'RWB'].iloc[:,27:61].copy()

# %%
rb_df.describe() - rwb_df.describe()
# Out:
#          Crossing   Finishing  HeadingAccuracy  ShortPassing     Volleys  \
# count  546.000000  546.000000       546.000000    546.000000  546.000000
# mean    -0.177058   -1.286908         4.375686     -0.823885   -0.277193
# std      1.127966    0.891334        -0.227897      1.848054    0.316160
# min    -11.000000    0.000000       -10.000000    -10.000000    0.000000
# 25%     -1.000000   -2.000000         4.000000     -1.000000    0.000000
# 50%      0.500000   -2.500000         4.000000      0.000000   -1.000000
# 75%      0.000000    0.000000         4.000000      1.000000    0.000000
# max      5.000000    6.000000         8.000000      0.000000    5.000000
#
#         Dribbling       Curve  FKAccuracy  LongPassing  BallControl  ...  \
# count  546.000000  546.000000  546.000000   546.000000   546.000000  ...
# mean    -1.524623   -0.541242   -0.094581    -1.059414    -0.656874  ...
# std      1.402538    2.097218    0.261910     1.938789     1.138023  ...
# min    -14.000000   -6.000000   -8.000000    -4.000000    -9.000000  ...
# 25%     -1.000000   -4.000000   -1.000000    -1.000000     0.000000  ...
# 50%     -1.000000    1.000000   -1.000000     0.000000     0.000000  ...
# 75%     -1.000000    2.000000    2.000000     1.000000     0.000000  ...
# max      8.000000    5.000000   10.000000    12.000000     0.000000  ...
#
#         Penalties   Composure    Marking  StandingTackle  SlidingTackle  \
# count  546.000000  547.000000  12.000000      546.000000     546.000000
# mean     1.065571    0.007329  -1.237154        1.484165       1.808781
# std      0.292720    0.703201  -4.266491        0.143459       0.149987
# min     -9.000000  -18.000000   7.000000       -3.000000      -4.000000
# 25%      1.000000    0.000000   0.500000        1.000000       2.000000
# 50%      1.000000    0.000000  -3.000000        1.000000       2.000000
# 75%      2.000000    1.000000  -2.000000        2.000000       3.000000
# max     -3.000000   -9.000000 -10.000000       -3.000000      -9.000000
#
#          GKDiving  GKHandling   GKKicking  GKPositioning  GKReflexes
# count  546.000000  546.000000  546.000000     546.000000  546.000000
# mean    -0.175724    0.365941    0.229748      -0.149465    0.355502
# std      0.025960    0.116087    0.111802      -0.020999   -0.075555
# min      0.000000    0.000000   -1.000000       0.000000    0.000000
# 25%      0.000000    0.000000    0.000000       0.000000    0.000000
# 50%      0.000000    0.000000    0.000000      -1.000000    0.000000
# 75%      0.000000    0.250000    0.000000       0.000000    0.000000
# max      0.000000    3.000000    2.000000       2.000000   -2.000000
#
# [8 rows x 34 columns]

# %% [markdown]
# ## 선수 가치 예측

# %%
df['Release Clause'] = df['Release Clause'].fillna('0'); df['Release Clause']
# Out:
# 0        €206.9M
# 1        €160.4M
# 2         €91.2M
# 3        €232.2M
# 4         €77.7M
#           ...
# 16705      €238K
# 16706      €279K
# 16707      €223K
# 16708      €259K
# 16709          0
# Name: Release Clause, Length: 16710, dtype: object

# %%
df['Release Clause'] = df['Release Clause'].map(lambda x : re.sub('[€]','',x))
df['Release Clause'] = df['Release Clause'].map(lambda x : float(re.sub('[^\.\d]','',x)) * 1000 if 'M' in x
                                                else float(re.sub('[^\.\d]','',x)))

# %%
plt.figure(dpi = 100)
sns.scatterplot(x = 'Overall', y = 'Release Clause', data = df, alpha = 0.5)
plt.show()

# %%
plt.figure(dpi = 100)
sns.scatterplot(x = 'Age', y = 'Release Clause', data = df, alpha = 0.5)
plt.show()

# %%
import numpy as np
df['Release Clause'] = df['Release Clause'].replace(0, np.nan)

# %%
reg_df = df.dropna(subset = ['Release Clause']).copy()

# %%
x = reg_df.iloc[:,27:61]
x = pd.concat([reg_df[['Age','Overall','Potential']], x], axis = 1)

# %%
x.drop('Marking', axis = 1, inplace = True); x
# Out:
#        Age  Overall  Potential  Crossing  Finishing  HeadingAccuracy  \
# 0       26       88         89      87.0       83.0             64.0
# 1       26       87         88      75.0       82.0             86.0
# 2       34       88         88      80.0       93.0             84.0
# 3       30       91         91      94.0       82.0             55.0
# 4       29       84         84      87.0       66.0             58.0
# ...    ...      ...        ...       ...        ...              ...
# 16704   20       58         69       8.0        9.0             11.0
# 16705   17       53         70      12.0        5.0             13.0
# 16706   20       53         63      13.0        7.0             10.0
# 16707   19       47         60      12.0        9.0             14.0
# 16708   18       47         67      13.0        8.0             10.0
#
#        ShortPassing  Volleys  Dribbling  Curve  ...  Vision  Penalties  \
# 0              91.0     87.0       83.0   87.0  ...    90.0       91.0
# 1              86.0     69.0       84.0   76.0  ...    84.0       60.0
# 2              83.0     90.0       83.0   86.0  ...    84.0       83.0
# 3              94.0     82.0       88.0   85.0  ...    94.0       83.0
# 4              82.0     68.0       87.0   88.0  ...    82.0       76.0
# ...             ...      ...        ...    ...  ...     ...        ...
# 16704          23.0      7.0       11.0   11.0  ...    27.0        7.0
# 16705          18.0      7.0       12.0   11.0  ...    29.0       18.0
# 16706          17.0      7.0        6.0   11.0  ...    33.0       12.0
# 16707          15.0      6.0        8.0   12.0  ...    18.0       15.0
# 16708          22.0      8.0       10.0   11.0  ...    31.0       19.0
#
#        Composure  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0           87.0            73.0           65.0      12.0        14.0
# 1           82.0            85.0           77.0      13.0         8.0
# 2           87.0            45.0           38.0      27.0        25.0
# 3           89.0            65.0           53.0      15.0        13.0
# 4           87.0            84.0           82.0       8.0        14.0
# ...          ...             ...            ...       ...         ...
# 16704       29.0            12.0           10.0      59.0        60.0
# 16705       37.0            11.0           12.0      55.0        54.0
# 16706       29.0            13.0           12.0      57.0        52.0
# 16707       17.0            11.0            9.0      49.0        48.0
# 16708       23.0            14.0           13.0      49.0        41.0
#
#        GKKicking  GKPositioning  GKReflexes
# 0           15.0            8.0        14.0
# 1           15.0           11.0         9.0
# 2           31.0           33.0        37.0
# 3            5.0           10.0        13.0
# 4           13.0           13.0        14.0
# ...          ...            ...         ...
# 16704       56.0           55.0        61.0
# 16705       52.0           50.0        59.0
# 16706       53.0           48.0        58.0
# 16707       45.0           38.0        52.0
# 16708       39.0           45.0        49.0
#
# [14961 rows x 36 columns]

# %%
y = df.dropna(subset = ['Release Clause'])['Release Clause'].copy(); y
# Out:
# 0        206900.0
# 1        160400.0
# 2         91200.0
# 3        232200.0
# 4         77700.0
#            ...
# 16704       656.0
# 16705       238.0
# 16706       279.0
# 16707       223.0
# 16708       259.0
# Name: Release Clause, Length: 14961, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 319)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

lin = LinearRegression()
lin.fit(x_train, y_train)
y_pred = lin.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('MSE:', np.round(mse, 4), 'RMSE:', np.round(rmse, 4))
print('R2:', np.round(r2, 4))
# Out:
# MSE: 166332985.8464 RMSE: 12897.0146
# R2: 0.4215

# %%
from sklearn.svm import SVR
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('svr', SVR())
                     ])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('MSE:', np.round(mse, 4), 'RMSE:', np.round(rmse, 4))
print('R2:', np.round(r2, 4))
# Out:
# MSE: 302592457.0213 RMSE: 17395.1849
# R2: -0.0523

# %%
from sklearn.neighbors import KNeighborsRegressor
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('knnrg', KNeighborsRegressor())
                     ])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('MSE:', np.round(mse, 4), 'RMSE:', np.round(rmse, 4))
print('R2:', np.round(r2, 4))
# Out:
# MSE: 49719248.2207 RMSE: 7051.1877
# R2: 0.8271

# %%
from sklearn.tree import DecisionTreeRegressor
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('dtrg', DecisionTreeRegressor())
                     ])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('MSE:', np.round(mse, 4), 'RMSE:', np.round(rmse, 4))
print('R2:', np.round(r2, 4))
# Out:
# MSE: 16865063.3054 RMSE: 4106.7095
# R2: 0.9413

# %%
from sklearn.ensemble import RandomForestRegressor
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('rfrg', RandomForestRegressor())
                     ])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('MSE:', np.round(mse, 4), 'RMSE:', np.round(rmse, 4))
print('R2:', np.round(r2, 4))
# Out:
# MSE: 8841932.2365 RMSE: 2973.5387
# R2: 0.9693

# %%
from xgboost import XGBRegressor
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('xgbr', XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0,objective='reg:squarederror',
                                           subsample=0.75, colsample_bytree=1, max_depth=15, random_state = 319))
                     ])

pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('MSE:', np.round(mse, 4), 'RMSE:', np.round(rmse, 4))
print('R2:', np.round(r2, 4))
# Out:
# MSE: 7308772.3099 RMSE: 2703.4741
# R2: 0.9746
